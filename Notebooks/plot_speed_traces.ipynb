# %% [markdown]
# # Overlaying speed traces of two laps
#
# Compare two fastest laps by overlaying their speed traces.

# %%
import matplotlib.pyplot as plt

import fastf1.plotting


# Enable Matplotlib patches for plotting timedelta values and load
# FastF1's dark color scheme
fastf1.plotting.setup_mpl(mpl_timedelta_support=True, color_scheme='fastf1')

# load a session and its telemetry data
session = fastf1.get_session(2021, 'Spanish Grand Prix', 'Q')
session.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (24.0 KB) C:\Users\aguse\AppData\Local\Temp\fastf1
# logger      WARNING 	Failed to load schedule from FastF1 backend!
# req            INFO 	No cached data found for season_schedule. Loading data...
# _api           INFO 	Fetching season schedule...
# logger      WARNING 	Failed to load schedule from F1 API backend!
# logger      WARNING 	Failed to load schedule from Ergast API backend!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 11
#       8 fastf1.plotting.setup_mpl(mpl_timedelta_support=True, color_scheme='fastf1')
#      10 # load a session and its telemetry data
# ---> 11 session = fastf1.get_session(2021, 'Spanish Grand Prix', 'Q')
#      12 session.load()
#
# File ~\OneDrive\Escritorio\PRY_AG\F1-analitics\venv\Lib\site-packages\fastf1\events.py:122, in get_session(year, gp, identifier, backend, force_ergast)
#      53 def get_session(
#      54         year: int,
#      55         gp: Union[str, int],
#    (...)     59         force_ergast: bool = False,
#      60 ) -> Session:
#      61     """Create a :class:`~fastf1.core.Session` object based on year, event name
#      62     and session identifier.
#      63
#    (...)    120             from the ergast database to create the event schedule
#     121     """
# --> 122     event = get_event(year, gp, force_ergast=force_ergast, backend=backend)
#     123     return event.get_session(identifier)
#
# File ~\OneDrive\Escritorio\PRY_AG\F1-analitics\venv\Lib\site-packages\fastf1\events.py:217, in get_event(year, gp, backend, force_ergast, strict_search, exact_match)
#     162 def get_event(
#     163         year: int,
#     164         gp: Union[int, str],
#    (...)    169         exact_match: bool = False
#     170 ) -> "Event":
#     171     """Create an :class:`~fastf1.events.Event` object for a specific
#     172     season and gp.
#     173
#    (...)    215     .. versionadded:: 2.2
#     216     """
# --> 217     schedule = get_event_schedule(year=year, include_testing=False,
#     218                                   force_ergast=force_ergast,
#     219                                   backend=backend)
#     221     if isinstance(gp, str):
#     222         event = schedule.get_event_by_name(
#     223             gp, strict_search=strict_search, exact_match=exact_match)
#
# File ~\OneDrive\Escritorio\PRY_AG\F1-analitics\venv\Lib\site-packages\fastf1\events.py:334, in get_event_schedule(year, include_testing, backend, force_ergast)
#     331         break
#     333 if schedule is None:  # raise Error if fallback failed as well
# --> 334     raise ValueError("Failed to load any schedule data.")
#     336 if not include_testing:
#     337     schedule = schedule[~schedule.is_testing()]
#
# ValueError: Failed to load any schedule data.

# %% [markdown]
# First, we select the two laps that we want to compare

# %%
ver_lap = session.laps.pick_drivers('VER').pick_fastest()
ham_lap = session.laps.pick_drivers('HAM').pick_fastest()

# %% [markdown]
# Next we get the telemetry data for each lap. We also add a 'Distance' column
# to the telemetry dataframe as this makes it easier to compare the laps.

# %%
ver_tel = ver_lap.get_car_data().add_distance()
ham_tel = ham_lap.get_car_data().add_distance()

# %% [markdown]
# Finally, we create a plot and plot both speed traces.
# We color the individual lines with the driver's team colors.

# %%
rbr_color = fastf1.plotting.get_team_color(ver_lap['Team'], session=session)
mer_color = fastf1.plotting.get_team_color(ham_lap['Team'], session=session)

fig, ax = plt.subplots()
ax.plot(ver_tel['Distance'], ver_tel['Speed'], color=rbr_color, label='VER')
ax.plot(ham_tel['Distance'], ham_tel['Speed'], color=mer_color, label='HAM')

ax.set_xlabel('Distance in m')
ax.set_ylabel('Speed in km/h')

ax.legend()
plt.suptitle(f"Fastest Lap Comparison \n "
             f"{session.event['EventName']} {session.event.year} Qualifying")

plt.show()
